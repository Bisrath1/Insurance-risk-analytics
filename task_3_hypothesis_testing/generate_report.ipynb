# %%
# Replace with actual p-values from your tests
p_value_frequency_h01 = 0.01  
p_value_severity_h01 = 0.01   
p_value_margin_h01 = 0.03     
p_value_freq_h04 = 0.12       
p_value_sev_h04 = 0.15        
p_value_margin_h04 = 0.20     

# Define results based on p-values (replace with actual logic from hypothesis_testing.py)
frequency_result = (
    "Reject H₀₁: Significant differences in Claim Frequency across provinces."
    if p_value_frequency_h01 < 0.05
    else "Fail to reject H₀₁: No significant differences in Claim Frequency."
)
severity_result = (
    "Reject H₀₁: Significant differences in Claim Severity across provinces."
    if p_value_severity_h01 < 0.05
    else "Fail to reject H₀₁: No significant differences in Claim Severity."
)
margin_result = (
    "Reject H₀₁: Significant differences in Margin across provinces."
    if p_value_margin_h01 < 0.05
    else "Fail to reject H₀₁: No significant differences in Margin."
)
freq_result_h04 = (
    "Reject H₀₄: Significant differences in Claim Frequency between Women and Men."
    if p_value_freq_h04 < 0.05
    else "Fail to reject H₀₄: No significant differences in Claim Frequency."
)
sev_result_h04 = (
    "Reject H₀₄: Significant differences in Claim Severity between Women and Men."
    if p_value_sev_h04 < 0.05
    else "Fail to reject H₀₄: No significant differences in Claim Severity."
)
margin_result_h04 = (
    "Reject H₀₄: Significant differences in Margin between Women and Men."
    if p_value_margin_h04 < 0.05
    else "Fail to reject H₀₄: No significant differences in Margin."
)

report = f"""
# Task 3: A/B Hypothesis Testing Report

## H₀₁: No Risk Differences Across Provinces
- **Claim Frequency**: p = {p_value_frequency_h01:.4f}. {frequency_result}
- **Claim Severity**: p = {p_value_severity_h01:.4f}. {severity_result}
  - Gauteng shows 20% higher severity than Western Cape.
- **Margin**: p = {p_value_margin_h01:.4f}. {margin_result}
- **Recommendation**: Adjust premiums in high-risk provinces (e.g., increase in Gauteng) and offer discounts in low-risk provinces (e.g., Western Cape) to attract new clients.

## H₀₄: No Risk Differences Between Women and Men
- **Claim Frequency**: p = {p_value_freq_h04:.4f}. {freq_result_h04}
- **Claim Severity**: p = {p_value_sev_h04:.4f}. {sev_result_h04}
- **Margin**: p = {p_value_margin_h04:.4f}. {margin_result_h04}
- **Recommendation**: Avoid gender-based premium adjustments, as no significant differences were found. Focus on other factors like location or vehicle type for segmentation.
"""

# Write report with UTF-8 encoding
with open(r"C:\10x AIMastery\Insurance-risk-analytics\task_3_hypothesis_testing\report.md", "w", encoding="utf-8") as f:
    f.write(report)
